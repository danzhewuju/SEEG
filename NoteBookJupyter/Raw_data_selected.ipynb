# %%
## 文件路径的基本设置

# %%
import os
import sys
sys.path.append("../")
import numpy as np
from util.seeg_utils import  *
import matplotlib.pyplot as plt
save_dir = "raw_data/save_raw_data"

# %%
pre_1_path = "/home/cbd109-3/Users/data/yh/Program/Python/SEEG/data/raw_data/BDP/BDP_Pre_seizure/BDP_SZ1_pre_seizure_raw.fif"
pre_2_path = "/home/cbd109-3/Users/data/yh/Program/Python/SEEG/data/raw_data/BDP/BDP_Pre_seizure/BDP_SZ2_pre_seizure_raw.fif"

# %% [markdown]
# ## 1. 第一个人的图像

# %%
pre_1_raw_data = read_raw(pre_1_path)
print(pre_1_raw_data.info['ch_names'])

# %%
select_channel_data = select_channel_data(pre_1_raw_data, ['POL E8'])

# %%
save_name = "e076f2d8-2552-11ea-9699-e0d55e6ff654-4.npy"
save_path = os.path.join(save_dir, save_name+"cluster_0.pdf")
print(select_channel_data.shape)
sampling = 1000
start = 8
end = 10
data = select_channel_data[:, start*sampling: end*sampling]
data = data.flatten()
print(data.shape)
plt.figure()
plt.plot()
x = np.arange(0, 2, 1/1000)
plt.plot(x, data*1e6)
plt.xlabel("Time [sec]")
plt.ylabel("Voltage [uv]")
plt.savefig(save_path)
plt.show()

# %%
# 4
pre_2_raw_data = read_raw(pre_2_path)
# Out:
# Opening raw data file /home/cbd109-3/Users/data/yh/Program/Python/SEEG/data/raw_data/BDP/BDP_Pre_seizure/BDP_SZ2_pre_seizure_raw.fif...
# Isotrak not found
#     Range : 696000 ... 4266000 =    696.000 ...  4266.000 secs
# Ready.
# Reading 0 ... 3570000  =      0.000 ...  3570.000 secs...

# %%
select_channel_data = select_channel_data(pre_2_raw_data, ['POL A7'])
save_name = "b15470c2-2555-11ea-9699-e0d55e6ff654-0.npy"
save_path = os.path.join(save_dir, save_name+"cluster_4.pdf")
print(select_channel_data.shape)
sampling = 1000
start = 3348
end = 3350
y = select_channel_data[:, start*sampling: end*sampling]
y = y.flatten()
print(y.shape)
plt.figure()
plt.plot()
x = np.arange(0, 2, 1/1000)
plt.plot(x, y*1e6)
plt.xlabel("Time [sec]")
plt.ylabel("Voltage [uv]")
plt.savefig(save_path)
plt.show()

# %%
# 0
pre_2_raw_data_0 = read_raw(pre_2_path)
select_channel_data = select_channel_data(pre_2_raw_data_0, ['POL B13'])
save_name = "b1547012-2555-11ea-9699-e0d55e6ff654-0.npy"
save_path = os.path.join(save_dir, save_name+"cluster_0.pdf")
print(select_channel_data.shape)
sampling = 1000
start = 2996
end = 2998
y = select_channel_data[:, start*sampling: end*sampling]
y = y.flatten()
print(y.shape)
plt.figure()
plt.plot()
x = np.arange(0, 2, 1/1000)
plt.plot(x, y*1e6)
plt.xlabel("Time [sec]")
plt.ylabel("Voltage [uv]")
plt.savefig(save_path)
plt.show()
# Out:
# Opening raw data file /home/cbd109-3/Users/data/yh/Program/Python/SEEG/data/raw_data/BDP/BDP_Pre_seizure/BDP_SZ2_pre_seizure_raw.fif...
# Isotrak not found
#     Range : 696000 ... 4266000 =    696.000 ...  4266.000 secs
# Ready.
# Reading 0 ... 3570000  =      0.000 ...  3570.000 secs...
# (1, 3570001)
# (2000,)

# %%
# 1
select_channel_data_A7 = select_channel_data(pre_2_raw_data, ['POL G8'])
save_name = "b12e66e4-2555-11ea-9699-e0d55e6ff654-0.npy"
save_path = os.path.join(save_dir, save_name+"cluster_1.pdf")
print(select_channel_data_A7.shape)
sampling = 1000
start = 520
end = 522
y = select_channel_data_A7[:, start*sampling: end*sampling]
y = y.flatten()
print(y.shape)
plt.figure()
plt.plot()
x = np.arange(0, 2, 1/1000)
plt.plot(x, y*1e6)
plt.xlabel("Time [sec]")
plt.ylabel("Voltage [uv]")
plt.savefig(save_path)
plt.show()
# Out:
# (1, 3570001)
# (2000,)

# %%
# 2

select_channel_data_A7 = select_channel_data(pre_2_raw_data, ['POL B13'])
save_name = "b12e6900-2555-11ea-9699-e0d55e6ff654-0.npy"
save_path = os.path.join(save_dir, save_name+"cluster_2.pdf")
print(select_channel_data_A7.shape)
sampling = 1000
start = 1600
end = 1602
y = select_channel_data_A7[:, start*sampling: end*sampling]
y = y.flatten()
print(y.shape)
plt.figure()
plt.plot()
x = np.arange(0, 2, 1/1000)
plt.plot(x, y*1e6)
plt.xlabel("Time [sec]")
plt.ylabel("Voltage [uv]")
plt.savefig(save_path)
plt.show()
# Out:
# (1, 3570001)
# (2000,)

# %%
# 3
select_channel_data_A7 = select_channel_data(pre_2_raw_data, ['POL B7'])
save_name = "b1546ea0-2555-11ea-9699-e0d55e6ff654-0.npy"
save_path = os.path.join(save_dir, save_name+"cluster_3.pdf")
print(select_channel_data_A7.shape)
sampling = 1000
start = 2256
end = 2258
y = select_channel_data_A7[:, start*sampling: end*sampling]
y = y.flatten()
print(y.shape)
plt.figure()
plt.plot()
x = np.arange(0, 2, 1/1000)
plt.plot(x, y*1e6)
plt.xlabel("Time [sec]")
plt.ylabel("Voltage [uv]")
plt.savefig(save_path)
plt.show()
# Out:
# (1, 3570001)
# (2000,)

# %%
def spectrogram_draw(data_test):
    duration_time = 2
    x = np.arange(0, duration_time, 1/1000)
    plt.plot(x, data_test)
    plt.xlabel("Time [sec]")
    plt.ylabel("Voltage [v]")
    NFFT = 100
    Fs = 1000
    plt.show()
    Pxx, freqs, bins, im = plt.specgram(data_test, NFFT=NFFT, Fs=Fs, noverlap=0)
    plt.xlabel("Time [sec]")
    plt.ylabel("Frequency [Hz]")
    plt.show()

t = np.arange(0, 2, 1/2000)
s1 = np.sin(2 * np.pi * 400 * t)
s2 = 2 * np.sin(2 * np.pi * 300 * t)
y  = s1+s2+10 * np.sin(2 * np.pi * 600 * t)
spectrogram_draw(data)
spectrogram_draw(y)
