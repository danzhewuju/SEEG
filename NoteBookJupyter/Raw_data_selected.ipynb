# %%
## 文件路径的基本设置

# %%
import sys
sys.path.append("../")
from util.seeg_utils import  *
import matplotlib.pyplot as plt
save_dir = "raw_data/save_raw_data"

# %%
pre_1_path = "/home/cbd109-3/Users/data/yh/Program/Python/SEEG/data/raw_data/BDP/BDP_Pre_seizure/BDP_SZ1_pre_seizure_raw.fif"
pre_2_path = "/home/cbd109-3/Users/data/yh/Program/Python/SEEG/data/raw_data/BDP/BDP_Pre_seizure/BDP_SZ2_pre_seizure_raw.fif"

# %% [markdown]
# ## 1. 第一个人的图像

# %%
pre_2_raw_data = read_raw(pre_2_path)
print(pre_2_raw_data.info['ch_names'])
# Out:
# Opening raw data file /home/cbd109-3/Users/data/yh/Program/Python/SEEG/data/raw_data/BDP/BDP_Pre_seizure/BDP_SZ2_pre_seizure_raw.fif...
# Isotrak not found
#     Range : 696000 ... 4266000 =    696.000 ...  4266.000 secs
# Ready.
# Reading 0 ... 3570000  =      0.000 ...  3570.000 secs...
# ['POL B1', 'POL B2', 'POL B3', 'POL B4', 'POL B5', 'POL B6', 'POL B7', 'POL B8', 'POL B9', 'POL B10', 'POL B13', 'POL B14', 'POL B15', 'POL B16', 'EEG A1-Ref', 'EEG A2-Ref', 'POL A3', 'POL A4', 'POL A5', 'POL A6', 'POL A7', 'POL B11', 'POL B12', 'POL A8', 'POL A9', 'POL A10', 'POL A11', 'POL A12', 'POL A13', 'POL A14', 'POL A15', 'POL A16', 'EEG C1-Ref', 'EEG C2-Ref', 'EEG C3-Ref', 'EEG C4-Ref', 'EEG C5-Ref', 'EEG C6-Ref', 'POL C7', 'POL C8', 'POL C9', 'POL C10', 'POL C11', 'POL C12', 'POL C13', 'POL C14', 'POL D1', 'POL D2', 'POL D3', 'POL D4', 'POL D5', 'POL D6', 'POL D7', 'POL D8', 'POL D9', 'POL D10', 'POL D11', 'POL D12', 'POL D13', 'POL D14', 'POL D15', 'POL D16', 'POL E1', 'POL E2', 'POL E3', 'POL E4', 'POL E5', 'POL E6', 'POL E7', 'POL E8', 'POL E9', 'POL E10', 'POL E11', 'POL E12', 'POL E13', 'POL E14', 'POL E15', 'POL E16', 'EEG F1-Ref', 'EEG F2-Ref', 'EEG F3-Ref', 'EEG F4-Ref', 'EEG F5-Ref', 'EEG F6-Ref', 'EEG F7-Ref', 'EEG F8-Ref', 'EEG F9-Ref', 'EEG F10-Ref', 'POL F11', 'POL F12', 'POL F13', 'POL F14', 'POL G1', 'POL G2', 'POL G3', 'POL G4', 'POL G5', 'POL G6', 'POL G7', 'POL G8', 'POL G9', 'POL G10', 'POL G11', 'POL G12', 'POL G13', 'POL G14', 'POL G15', 'POL G16', 'POL H1', 'POL H2', 'POL H3', 'POL H4', 'POL H5', 'POL H6', 'POL H7', 'POL H8', 'POL H9', 'POL H10', 'POL H11', 'POL H12', 'POL I1', 'POL I2', 'POL I3', 'POL I4', 'POL I5', 'POL I6', 'POL I7', 'POL I8', 'POL I9', 'POL I10', 'POL J1', 'POL J2', 'POL J3', 'POL J4', 'POL J5', 'POL J6', 'POL J7', 'POL J8', 'POL J9', 'POL J10', 'POL J11', 'POL J12', 'POL J13', 'POL J14', 'POL J15', 'POL J16']
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()

# %%
select_channel_data = select_channel_data(pre_2_raw_data, ['POL B15'])

# %%
# save_name = "b1547062-2555-11ea-9699-e0d55e6ff654-0.npy"
# save_path = os.path.join(save_dir, save_name+"cluster_0.pdf")
# print(select_channel_data.shape)
# sampling = 1000
# start = 3156
# end = 3158
# data = select_channel_data[:, start*sampling: end*sampling]
# data = data.flatten()
# print(data.shape)
# plt.figure()
# plt.plot()
# x = np.arange(0, 2, 1/1000)
# plt.plot(x, data*1e6)
# plt.xlabel("Time [sec]")
# plt.ylabel("Voltage [uv]")
# plt.savefig(save_path)
# plt.show()
# Out:
# (1, 3570001)
# (2000,)

# %%
# 1
pre_1_raw_data = read_raw(pre_1_path)
select_channel_data_J14 = select_channel_data(pre_1_raw_data, ['POL J14'])
save_name = "e076f342-2552-11ea-9699-e0d55e6ff654-0.npy"
save_path = os.path.join(save_dir, save_name+"cluster_1.pdf")
print(select_channel_data_J14.shape)
sampling = 1000
start = 220
end = 222
y = select_channel_data_J14[:, start*sampling: end*sampling]
y = y.flatten()
print(y.shape)
plt.figure()
plt.plot()
x = np.arange(0, 2, 1/1000)
plt.plot(x, y*1e6)
plt.xlabel("Time [sec]")
plt.ylabel("Voltage [uv]")
plt.savefig(save_path)
plt.show()
# Out:
# Opening raw data file /home/cbd109-3/Users/data/yh/Program/Python/SEEG/data/raw_data/BDP/BDP_Pre_seizure/BDP_SZ1_pre_seizure_raw.fif...
# Isotrak not found
#     Range : 0 ... 621000 =      0.000 ...   621.000 secs
# Ready.
# Reading 0 ... 621000  =      0.000 ...   621.000 secs...
# (1, 621001)
# (2000,)
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:268: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   return str(d.tostring().decode('latin1', 'ignore'))

# %%
# 4
pre_2_raw_data = read_raw(pre_2_path)
# Out:
# Opening raw data file /home/cbd109-3/Users/data/yh/Program/Python/SEEG/data/raw_data/BDP/BDP_Pre_seizure/BDP_SZ2_pre_seizure_raw.fif...
# Isotrak not found
#     Range : 696000 ... 4266000 =    696.000 ...  4266.000 secs
# Ready.
# Reading 0 ... 3570000  =      0.000 ...  3570.000 secs...
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()

# %%
select_channel_data = select_channel_data(pre_2_raw_data, ['POL E9'])
save_name = "b1546ea4-2555-11ea-9699-e0d55e6ff654-0.npy"
save_path = os.path.join(save_dir, save_name+"cluster_4.pdf")
print(select_channel_data.shape)
sampling = 1000
start = 2264
end = 2266
y = select_channel_data[:, start*sampling: end*sampling]
y = y.flatten()
print(y.shape)
plt.figure()
plt.plot()
x = np.arange(0, 2, 1/1000)
plt.plot(x, y*1e6)
plt.xlabel("Time [sec]")
plt.ylabel("Voltage [uv]")
plt.savefig(save_path)
plt.show()
# Out:
# (1, 3570001)
# (2000,)

# %%
# 0
# pre_2_raw_data_0 = read_raw(pre_2_path)
pre_2_raw_data = read_raw(pre_2_path)
select_channel_data = select_channel_data(pre_2_raw_data, ['POL B13'])
save_name = "b1547012-2555-11ea-9699-e0d55e6ff654-0.npy"
save_path = os.path.join(save_dir, save_name+"cluster_1.pdf")
print(select_channel_data.shape)
sampling = 1000
start = 2996
end = 2998
y = select_channel_data[:, start*sampling: end*sampling]
y = y.flatten()
print(y.shape)
plt.figure()
plt.plot()
x = np.arange(0, 2, 1/1000)
plt.plot(x, y*1e6)
plt.xlabel("Time [sec]")
plt.ylabel("Voltage [uv]")
plt.savefig(save_path)
plt.show()
# Out:
# Opening raw data file /home/cbd109-3/Users/data/yh/Program/Python/SEEG/data/raw_data/BDP/BDP_Pre_seizure/BDP_SZ2_pre_seizure_raw.fif...
# Isotrak not found
#     Range : 696000 ... 4266000 =    696.000 ...  4266.000 secs
# Ready.
# Reading 0 ... 3570000  =      0.000 ...  3570.000 secs...
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-21-6cad89ffc8ed> in <module>
#       2 # pre_2_raw_data_0 = read_raw(pre_2_path)
#       3 pre_2_raw_data = read_raw(pre_2_path)
# ----> 4 select_channel_data = select_channel_data(pre_2_raw_data, ['POL B13'])
#       5 save_name = "b1547012-2555-11ea-9699-e0d55e6ff654-0.npy"
#       6 save_path = os.path.join(save_dir, save_name+"cluster_1.pdf")
#
# TypeError: 'numpy.ndarray' object is not callable

# %%
# 2
pre_2_raw_data_2 = read_raw(pre_2_path)
select_channel_data_B13 = select_channel_data(pre_2_raw_data_2, ['POL B13'])
save_name = "b12e6900-2555-11ea-9699-e0d55e6ff654-0.npy"
save_path = os.path.join(save_dir, save_name+"cluster_2.pdf")
print(select_channel_data_B13.shape)
sampling = 1000
start = 1600
end = 1602
y = select_channel_data_B13[:, start*sampling: end*sampling]
y = y.flatten()
print(y.shape)
plt.figure()
plt.plot()
x = np.arange(0, 2, 1/1000)
plt.plot(x, y*1e6)
plt.xlabel("Time [sec]")
plt.ylabel("Voltage [uv]")
plt.savefig(save_path)
plt.show()
# Out:
# Opening raw data file /home/cbd109-3/Users/data/yh/Program/Python/SEEG/data/raw_data/BDP/BDP_Pre_seizure/BDP_SZ2_pre_seizure_raw.fif...
# Isotrak not found
#     Range : 696000 ... 4266000 =    696.000 ...  4266.000 secs
# Ready.
# Reading 0 ... 3570000  =      0.000 ...  3570.000 secs...
# (1, 3570001)
# (2000,)
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# /home/cbd109-3/applications/anaconda3/envs/ching/lib/python3.6/site-packages/mne/io/tag.py:347: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()

# %%
# 3
select_channel_data_A7 = select_channel_data(pre_2_raw_data, ['POL G5'])
save_name = "b12e684a-2555-11ea-9699-e0d55e6ff654-0.npy"
save_path = os.path.join(save_dir, save_name+"cluster_3.pdf")
print(select_channel_data_A7.shape)
sampling = 1000
start = 1236
end = 1238
y = select_channel_data_A7[:, start*sampling: end*sampling]
y = y.flatten()
print(y.shape)
plt.figure()
plt.plot()
x = np.arange(0, 2, 1/1000)
plt.plot(x, y*1e6)
plt.xlabel("Time [sec]")
plt.ylabel("Voltage [uv]")
plt.savefig(save_path)
plt.show()
# Out:
# (1, 3570001)
# (2000,)

# %%
def spectrogram_draw(data_test):
    duration_time = 2
    x = np.arange(0, duration_time, 1/1000)
    plt.plot(x, data_test)
    plt.xlabel("Time [sec]")
    plt.ylabel("Voltage [v]")
    NFFT = 100
    Fs = 1000
    plt.show()
    Pxx, freqs, bins, im = plt.specgram(data_test, NFFT=NFFT, Fs=Fs, noverlap=0)
    plt.xlabel("Time [sec]")
    plt.ylabel("Frequency [Hz]")
    plt.show()

t = np.arange(0, 2, 1/2000)
s1 = np.sin(2 * np.pi * 400 * t)
s2 = 2 * np.sin(2 * np.pi * 300 * t)
y  = s1+s2+10 * np.sin(2 * np.pi * 600 * t)
# spectrogram_draw(data)
spectrogram_draw(y)
